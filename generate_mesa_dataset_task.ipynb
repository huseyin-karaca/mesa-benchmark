# %%
# %matplotlib inline
import pandas as pd
import numpy as np
# required by pd.read_csv. It expects an object with a .read() method.
from datetime import datetime, timedelta
from glob import glob
from bs4 import BeautifulSoup
import gzip
import os

# %%
def getOverlap(mesaid, overlap_file="./data/mesa/overlap/mesa-actigraphy-psg-overlap.csv"):
    
    df = pd.read_csv(overlap_file)
    df = df[df["mesaid"] == mesaid]
    if df.empty:
        print("ERROR: mesaid %d not found in overlap file" % (mesaid))
        return None
    return df.values[0][1] # (mesaid, line, timeactigraph, timepsg)

def extractAcigraphy(mesaid):
    # Start to extract Actigraphy actValue
    try:
        act_file = "data/mesa/actigraphy/mesa-sleep-%04d.csv" % (mesaid)
        df = load_mesa(act_file)
        return df
    except:
        return None

def extractPSG(mesaid):
    # Start to extract PSG sleep scores
    profusion_file = "/home/huseyin/bitirme/mesa-benchmark/data/mesa/polysomnography/annotations-events-profusion/mesa-sleep-%04d-profusion.xml" % (mesaid)
    
    try:
        soup = BeautifulSoup(profusion_file, 'xml')

        stages = []
        for c in soup.CMPStudyConfig.SleepStages:
            stages.append(c.string)

        return stages
    except:
        return None

def load_mesa(filename):
    """
        Load all the mesa files
    """
    
    df = pd.read_csv(filename, index_col="line")
    
    ts = get_timestamp("1/1/1900", df.iloc[0]["linetime"])
    pts = pd.Timestamp(ts)
    df["linetime"] = pd.date_range(pts, periods=df.shape[0], freq='30S')
    
    return df

def get_timestamp(start_date, start_time):
    return datetime.strptime(start_date + " " + start_time, '%m/%d/%Y %H:%M:%S')

def get_time_interval(n):
    minutes = n / 2
    hours = minutes/ 60
    rest_minutes = minutes - (hours * 60)
    rest_seconds = "30" if n%2 == 1 else "00"
    return "%02d:%02d:%s" % (hours, rest_minutes, rest_seconds)

# %%
def process(mesaid, task):
    """
    - mesaid: Integer representing a valid mesaid.
    
    - task:
         * task1 (PSG time)
         * task2 (24 hours)
    """
    print("Processing %d..." % (mesaid))
    
    # Extract Actigraphy data
    df = extractAcigraphy(mesaid)
    if df is None:
        print ("Actigraphy not found for mesaid %d. Aborting..." % (mesaid))
        return None
    
    # Extract PSG data
    stages = extractPSG(mesaid)
    if stages is None:
        print ("PSG not found for mesaid %d. Aborting..." % (mesaid))
        return None
    
    stages = list(map(int, stages))

    # If recording for more than 16 hours, we do not use this mesaid
    if len(stages) > 1920:
        print ("PSG recording was longer than 16 hours for mesaid %d." % (mesaid))
        print ("Aborting...")
        return None
    
    # Extract overlap index
    overlapidx = getOverlap(mesaid)

    if overlapidx is None:
        print ("Problems with mesaid %d. Aborting..." % (mesaid))
        return None
    
    #return df, stages, overlapidx
    
    # Creates an extra col with PSG data and fills up data with stages
    df["stage"] = None
    df.loc[overlapidx:overlapidx+len(stages)-1, "stage"] = stages
    
    # Task 1: only PSG data is kept
    if task == 1:
        df = df[~df["stage"].isnull()]
        
    elif task == 2: # aims to get 960 (8 hours) intervals before and after PSG 
        startidx = max(0, overlapidx - 960)
        endidx = min(df.shape[0], overlapidx+len(stages)-1 + 960)
        df = df.loc[startidx: endidx]
    
    # Generates the ground truth data:
    if task == 1:
        df["gt"] = (df["stage"] > 0)
    
    elif task == 2:
        # ...uses GT as the PSG states and uses "interval" data for the rest....
        df["gt"] = None
        beforePSG = df.loc[:overlapidx-1].copy()
        duringPSG = df.loc[overlapidx: overlapidx+len(stages)-2].copy()
        afterPSG = df.loc[overlapidx+len(stages)-1:].copy()

        beforePSG["gt"] = beforePSG["interval"].apply(lambda x: x in ["REST", "REST-S"])
        afterPSG["gt"] = afterPSG["interval"].apply(lambda x: x in ["REST", "REST-S"])
        duringPSG["gt"] =  (duringPSG["stage"] > 0)
        df = pd.concat((beforePSG,duringPSG,afterPSG))
        
    df["gt"] = df["gt"].astype(np.int)
        
    dflenght = df.shape[0]
    print("Final df duration %s (%d intervals) -- From %s to %s" % (get_time_interval(dflenght),dflenght, df.head(1)["linetime"].values[0], df.tail(1)["linetime"].values[0]))

    # Resets index
    df = df.reset_index(drop=True)
    
    return df

# %%
process(1, 1)  # 2896, 4012 should be there...
# Out:
# Processing 1...
# PSG not found for mesaid 1. Aborting...

# %%
TASK = 1
outdir = "datasets"

variables_file = "./data/mesa/datasets/mesa-sleep-dataset-0.6.0.csv"
variables = pd.read_csv(variables_file)
ids = list(variables["mesaid"].unique())

problem = []
okays = 0
empties = []
processed = 0

for mesaid in ids[:]:
    
    processed += 1
    
    print("*" * 80)    
    df = process(mesaid, task=TASK)
    print("*" * 80)
    
    if df is None:
        print("Could not get data for mesaid %d" % (mesaid))
        problem.append(mesaid)
        continue
    
    if df[(df["interval"] == "EXCLUDED")].shape[0] > 0:
        print("FOUND %d rows to be excluded" % (df[(df["interval"] == "EXCLUDED")].shape[0]))
    
    if (df[df["interval"] == "EXCLUDED"].shape[0] == df.shape[0]) or df.empty:
        print("ERROR: All intervals were excluded.")
        print("MesaID %d is empty..." % mesaid)
        empties.append(mesaid)
        continue
    
    #df = df[df["interval"] != "EXCLUDED"] # TODO: not sure if I should keep or remove the excluded rows.
   
    outfile = "mesa_%000d_task%s.csv" % (mesaid, TASK)
    outpath = os.path.join(outdir, outfile)
        
    df.to_csv(outpath, index=False)
    okays += 1
    
print("Done with %d okay out of %d possible ids" % (okays, processed))
# Out:
# ********************************************************************************
# Processing 1...
# PSG not found for mesaid 1. Aborting...
# ********************************************************************************
# Could not get data for mesaid 1
# ********************************************************************************
# Processing 2...
# PSG not found for mesaid 2. Aborting...
# ********************************************************************************
# Could not get data for mesaid 2
# ********************************************************************************
# Processing 6...
# PSG not found for mesaid 6. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6
# ********************************************************************************
# Processing 10...
# PSG not found for mesaid 10. Aborting...
# ********************************************************************************
# Could not get data for mesaid 10
# ********************************************************************************
# Processing 12...
# PSG not found for mesaid 12. Aborting...
# ********************************************************************************
# Could not get data for mesaid 12
# ********************************************************************************
# Processing 14...
# PSG not found for mesaid 14. Aborting...
# ********************************************************************************
# Could not get data for mesaid 14
# ********************************************************************************
# Processing 16...
# PSG not found for mesaid 16. Aborting...
# ********************************************************************************
# Could not get data for mesaid 16
# ********************************************************************************
# Processing 21...
# PSG not found for mesaid 21. Aborting...
# ********************************************************************************
# Could not get data for mesaid 21
# ********************************************************************************
# Processing 27...
# PSG not found for mesaid 27. Aborting...
# ********************************************************************************
# Could not get data for mesaid 27
# ********************************************************************************
# Processing 28...
# PSG not found for mesaid 28. Aborting...
# ********************************************************************************
# Could not get data for mesaid 28
# ********************************************************************************
# Processing 29...
# PSG not found for mesaid 29. Aborting...
# ********************************************************************************
# Could not get data for mesaid 29
# ********************************************************************************
# Processing 33...
# PSG not found for mesaid 33. Aborting...
# ********************************************************************************
# Could not get data for mesaid 33
# ********************************************************************************
# Processing 35...
# PSG not found for mesaid 35. Aborting...
# ********************************************************************************
# Could not get data for mesaid 35
# ********************************************************************************
# Processing 36...
# PSG not found for mesaid 36. Aborting...
# ********************************************************************************
# Could not get data for mesaid 36
# ********************************************************************************
# Processing 38...
# PSG not found for mesaid 38. Aborting...
# ********************************************************************************
# Could not get data for mesaid 38
# ********************************************************************************
# Processing 46...
# PSG not found for mesaid 46. Aborting...
# ********************************************************************************
# Could not get data for mesaid 46
# ********************************************************************************
# Processing 48...
# PSG not found for mesaid 48. Aborting...
# ********************************************************************************
# Could not get data for mesaid 48
# ********************************************************************************
# Processing 50...
# PSG not found for mesaid 50. Aborting...
# ********************************************************************************
# Could not get data for mesaid 50
# ********************************************************************************
# Processing 52...
# PSG not found for mesaid 52. Aborting...
# ********************************************************************************
# Could not get data for mesaid 52
# ********************************************************************************
# Processing 54...
# PSG not found for mesaid 54. Aborting...
# ********************************************************************************
# Could not get data for mesaid 54
# ********************************************************************************
# Processing 56...
# PSG not found for mesaid 56. Aborting...
# ********************************************************************************
# Could not get data for mesaid 56
# ********************************************************************************
# Processing 64...
# PSG not found for mesaid 64. Aborting...
# ********************************************************************************
# Could not get data for mesaid 64
# ********************************************************************************
# Processing 70...
# PSG not found for mesaid 70. Aborting...
# ********************************************************************************
# Could not get data for mesaid 70
# ********************************************************************************
# Processing 74...
# PSG not found for mesaid 74. Aborting...
# ********************************************************************************
# Could not get data for mesaid 74
# ********************************************************************************
# Processing 77...
# PSG not found for mesaid 77. Aborting...
# ********************************************************************************
# Could not get data for mesaid 77
# ********************************************************************************
# Processing 79...
# PSG not found for mesaid 79. Aborting...
# ********************************************************************************
# Could not get data for mesaid 79
# ********************************************************************************
# Processing 81...
# PSG not found for mesaid 81. Aborting...
# ********************************************************************************
# Could not get data for mesaid 81
# ********************************************************************************
# Processing 84...
# PSG not found for mesaid 84. Aborting...
# ********************************************************************************
# Could not get data for mesaid 84
# ********************************************************************************
# Processing 85...
# PSG not found for mesaid 85. Aborting...
# ********************************************************************************
# Could not get data for mesaid 85
# ********************************************************************************
# Processing 87...
# PSG not found for mesaid 87. Aborting...
# ********************************************************************************
# Could not get data for mesaid 87
# ********************************************************************************
# Processing 93...
# PSG not found for mesaid 93. Aborting...
# ********************************************************************************
# Could not get data for mesaid 93
# ********************************************************************************
# Processing 99...
# PSG not found for mesaid 99. Aborting...
# ********************************************************************************
# Could not get data for mesaid 99
# ********************************************************************************
# Processing 101...
# PSG not found for mesaid 101. Aborting...
# ********************************************************************************
# Could not get data for mesaid 101
# ********************************************************************************
# Processing 105...
# PSG not found for mesaid 105. Aborting...
# ********************************************************************************
# Could not get data for mesaid 105
# ********************************************************************************
# Processing 107...
# PSG not found for mesaid 107. Aborting...
# ********************************************************************************
# Could not get data for mesaid 107
# ********************************************************************************
# Processing 109...
# PSG not found for mesaid 109. Aborting...
# ********************************************************************************
# Could not get data for mesaid 109
# ********************************************************************************
# Processing 110...
# PSG not found for mesaid 110. Aborting...
# ********************************************************************************
# Could not get data for mesaid 110
# ********************************************************************************
# Processing 111...
# PSG not found for mesaid 111. Aborting...
# ********************************************************************************
# Could not get data for mesaid 111
# ********************************************************************************
# Processing 113...
# PSG not found for mesaid 113. Aborting...
# ********************************************************************************
# Could not get data for mesaid 113
# ********************************************************************************
# Processing 117...
# PSG not found for mesaid 117. Aborting...
# ********************************************************************************
# Could not get data for mesaid 117
# ********************************************************************************
# Processing 118...
# PSG not found for mesaid 118. Aborting...
# ********************************************************************************
# Could not get data for mesaid 118
# ********************************************************************************
# Processing 120...
# PSG not found for mesaid 120. Aborting...
# ********************************************************************************
# Could not get data for mesaid 120
# ********************************************************************************
# Processing 121...
# PSG not found for mesaid 121. Aborting...
# ********************************************************************************
# Could not get data for mesaid 121
# ********************************************************************************
# Processing 125...
# PSG not found for mesaid 125. Aborting...
# ********************************************************************************
# Could not get data for mesaid 125
# ********************************************************************************
# Processing 128...
# PSG not found for mesaid 128. Aborting...
# ********************************************************************************
# Could not get data for mesaid 128
# ********************************************************************************
# Processing 132...
# PSG not found for mesaid 132. Aborting...
# ********************************************************************************
# Could not get data for mesaid 132
# ********************************************************************************
# Processing 133...
# PSG not found for mesaid 133. Aborting...
# ********************************************************************************
# Could not get data for mesaid 133
# ********************************************************************************
# Processing 134...
# PSG not found for mesaid 134. Aborting...
# ********************************************************************************
# Could not get data for mesaid 134
# ********************************************************************************
# Processing 138...
# PSG not found for mesaid 138. Aborting...
# ********************************************************************************
# Could not get data for mesaid 138
# ********************************************************************************
# Processing 139...
# PSG not found for mesaid 139. Aborting...
# ********************************************************************************
# Could not get data for mesaid 139
# ********************************************************************************
# Processing 140...
# PSG not found for mesaid 140. Aborting...
# ********************************************************************************
# Could not get data for mesaid 140
# ********************************************************************************
# Processing 144...
# PSG not found for mesaid 144. Aborting...
# ********************************************************************************
# Could not get data for mesaid 144
# ********************************************************************************
# Processing 149...
# PSG not found for mesaid 149. Aborting...
# ********************************************************************************
# Could not get data for mesaid 149
# ********************************************************************************
# Processing 152...
# PSG not found for mesaid 152. Aborting...
# ********************************************************************************
# Could not get data for mesaid 152
# ********************************************************************************
# Processing 155...
# PSG not found for mesaid 155. Aborting...
# ********************************************************************************
# Could not get data for mesaid 155
# ********************************************************************************
# Processing 159...
# PSG not found for mesaid 159. Aborting...
# ********************************************************************************
# Could not get data for mesaid 159
# ********************************************************************************
# Processing 167...
# PSG not found for mesaid 167. Aborting...
# ********************************************************************************
# Could not get data for mesaid 167
# ********************************************************************************
# Processing 168...
# PSG not found for mesaid 168. Aborting...
# ********************************************************************************
# Could not get data for mesaid 168
# ********************************************************************************
# Processing 169...
# PSG not found for mesaid 169. Aborting...
# ********************************************************************************
# Could not get data for mesaid 169
# ********************************************************************************
# Processing 171...
# PSG not found for mesaid 171. Aborting...
# ********************************************************************************
# Could not get data for mesaid 171
# ********************************************************************************
# Processing 179...
# PSG not found for mesaid 179. Aborting...
# ********************************************************************************
# Could not get data for mesaid 179
# ********************************************************************************
# Processing 182...
# PSG not found for mesaid 182. Aborting...
# ********************************************************************************
# Could not get data for mesaid 182
# ********************************************************************************
# Processing 183...
# PSG not found for mesaid 183. Aborting...
# ********************************************************************************
# Could not get data for mesaid 183
# ********************************************************************************
# Processing 187...
# PSG not found for mesaid 187. Aborting...
# ********************************************************************************
# Could not get data for mesaid 187
# ********************************************************************************
# Processing 188...
# PSG not found for mesaid 188. Aborting...
# ********************************************************************************
# Could not get data for mesaid 188
# ********************************************************************************
# Processing 193...
# PSG not found for mesaid 193. Aborting...
# ********************************************************************************
# Could not get data for mesaid 193
# ********************************************************************************
# Processing 194...
# PSG not found for mesaid 194. Aborting...
# ********************************************************************************
# Could not get data for mesaid 194
# ********************************************************************************
# Processing 195...
# PSG not found for mesaid 195. Aborting...
# ********************************************************************************
# Could not get data for mesaid 195
# ********************************************************************************
# Processing 196...
# PSG not found for mesaid 196. Aborting...
# ********************************************************************************
# Could not get data for mesaid 196
# ********************************************************************************
# Processing 197...
# PSG not found for mesaid 197. Aborting...
# ********************************************************************************
# Could not get data for mesaid 197
# ********************************************************************************
# Processing 199...
# PSG not found for mesaid 199. Aborting...
# ********************************************************************************
# Could not get data for mesaid 199
# ********************************************************************************
# Processing 204...
# PSG not found for mesaid 204. Aborting...
# ********************************************************************************
# Could not get data for mesaid 204
# ********************************************************************************
# Processing 209...
# PSG not found for mesaid 209. Aborting...
# ********************************************************************************
# Could not get data for mesaid 209
# ********************************************************************************
# Processing 211...
# PSG not found for mesaid 211. Aborting...
# ********************************************************************************
# Could not get data for mesaid 211
# ********************************************************************************
# Processing 214...
# PSG not found for mesaid 214. Aborting...
# ********************************************************************************
# Could not get data for mesaid 214
# ********************************************************************************
# Processing 219...
# PSG not found for mesaid 219. Aborting...
# ********************************************************************************
# Could not get data for mesaid 219
# ********************************************************************************
# Processing 220...
# PSG not found for mesaid 220. Aborting...
# ********************************************************************************
# Could not get data for mesaid 220
# ********************************************************************************
# Processing 225...
# PSG not found for mesaid 225. Aborting...
# ********************************************************************************
# Could not get data for mesaid 225
# ********************************************************************************
# Processing 236...
# PSG not found for mesaid 236. Aborting...
# ********************************************************************************
# Could not get data for mesaid 236
# ********************************************************************************
# Processing 241...
# PSG not found for mesaid 241. Aborting...
# ********************************************************************************
# Could not get data for mesaid 241
# ********************************************************************************
# Processing 248...
# PSG not found for mesaid 248. Aborting...
# ********************************************************************************
# Could not get data for mesaid 248
# ********************************************************************************
# Processing 251...
# PSG not found for mesaid 251. Aborting...
# ********************************************************************************
# Could not get data for mesaid 251
# ********************************************************************************
# Processing 255...
# PSG not found for mesaid 255. Aborting...
# ********************************************************************************
# Could not get data for mesaid 255
# ********************************************************************************
# Processing 258...
# PSG not found for mesaid 258. Aborting...
# ********************************************************************************
# Could not get data for mesaid 258
# ********************************************************************************
# Processing 269...
# PSG not found for mesaid 269. Aborting...
# ********************************************************************************
# Could not get data for mesaid 269
# ********************************************************************************
# Processing 271...
# PSG not found for mesaid 271. Aborting...
# ********************************************************************************
# Could not get data for mesaid 271
# ********************************************************************************
# Processing 275...
# PSG not found for mesaid 275. Aborting...
# ********************************************************************************
# Could not get data for mesaid 275
# ********************************************************************************
# Processing 282...
# PSG not found for mesaid 282. Aborting...
# ********************************************************************************
# Could not get data for mesaid 282
# ********************************************************************************
# Processing 284...
# PSG not found for mesaid 284. Aborting...
# ********************************************************************************
# Could not get data for mesaid 284
# ********************************************************************************
# Processing 285...
# PSG not found for mesaid 285. Aborting...
# ********************************************************************************
# Could not get data for mesaid 285
# ********************************************************************************
# Processing 286...
# PSG not found for mesaid 286. Aborting...
# ********************************************************************************
# Could not get data for mesaid 286
# ********************************************************************************
# Processing 288...
# PSG not found for mesaid 288. Aborting...
# ********************************************************************************
# Could not get data for mesaid 288
# ********************************************************************************
# Processing 292...
# PSG not found for mesaid 292. Aborting...
# ********************************************************************************
# Could not get data for mesaid 292
# ********************************************************************************
# Processing 295...
# PSG not found for mesaid 295. Aborting...
# ********************************************************************************
# Could not get data for mesaid 295
# ********************************************************************************
# Processing 299...
# PSG not found for mesaid 299. Aborting...
# ********************************************************************************
# Could not get data for mesaid 299
# ********************************************************************************
# Processing 301...
# PSG not found for mesaid 301. Aborting...
# ********************************************************************************
# Could not get data for mesaid 301
# ********************************************************************************
# Processing 303...
# PSG not found for mesaid 303. Aborting...
# ********************************************************************************
# Could not get data for mesaid 303
# ********************************************************************************
# Processing 306...
# PSG not found for mesaid 306. Aborting...
# ********************************************************************************
# Could not get data for mesaid 306
# ********************************************************************************
# Processing 310...
# PSG not found for mesaid 310. Aborting...
# ********************************************************************************
# Could not get data for mesaid 310
# ********************************************************************************
# Processing 312...
# PSG not found for mesaid 312. Aborting...
# ********************************************************************************
# Could not get data for mesaid 312
# ********************************************************************************
# Processing 314...
# Actigraphy not found for mesaid 314. Aborting...
# ********************************************************************************
# Could not get data for mesaid 314
# ********************************************************************************
# Processing 318...
# PSG not found for mesaid 318. Aborting...
# ********************************************************************************
# Could not get data for mesaid 318
# ********************************************************************************
# Processing 319...
# PSG not found for mesaid 319. Aborting...
# ********************************************************************************
# Could not get data for mesaid 319
# ********************************************************************************
# Processing 320...
# PSG not found for mesaid 320. Aborting...
# ********************************************************************************
# Could not get data for mesaid 320
# ********************************************************************************
# Processing 323...
# PSG not found for mesaid 323. Aborting...
# ********************************************************************************
# Could not get data for mesaid 323
# ********************************************************************************
# Processing 328...
# PSG not found for mesaid 328. Aborting...
# ********************************************************************************
# Could not get data for mesaid 328
# ********************************************************************************
# Processing 329...
# PSG not found for mesaid 329. Aborting...
# ********************************************************************************
# Could not get data for mesaid 329
# ********************************************************************************
# Processing 332...
# PSG not found for mesaid 332. Aborting...
# ********************************************************************************
# Could not get data for mesaid 332
# ********************************************************************************
# Processing 337...
# PSG not found for mesaid 337. Aborting...
# ********************************************************************************
# Could not get data for mesaid 337
# ********************************************************************************
# Processing 338...
# PSG not found for mesaid 338. Aborting...
# ********************************************************************************
# Could not get data for mesaid 338
# ********************************************************************************
# Processing 339...
# PSG not found for mesaid 339. Aborting...
# ********************************************************************************
# Could not get data for mesaid 339
# ********************************************************************************
# Processing 344...
# PSG not found for mesaid 344. Aborting...
# ********************************************************************************
# Could not get data for mesaid 344
# ********************************************************************************
# Processing 345...
# PSG not found for mesaid 345. Aborting...
# ********************************************************************************
# Could not get data for mesaid 345
# ********************************************************************************
# Processing 346...
# PSG not found for mesaid 346. Aborting...
# ********************************************************************************
# Could not get data for mesaid 346
# ********************************************************************************
# Processing 347...
# PSG not found for mesaid 347. Aborting...
# ********************************************************************************
# Could not get data for mesaid 347
# ********************************************************************************
# Processing 350...
# PSG not found for mesaid 350. Aborting...
# ********************************************************************************
# Could not get data for mesaid 350
# ********************************************************************************
# Processing 359...
# PSG not found for mesaid 359. Aborting...
# ********************************************************************************
# Could not get data for mesaid 359
# ********************************************************************************
# Processing 363...
# PSG not found for mesaid 363. Aborting...
# ********************************************************************************
# Could not get data for mesaid 363
# ********************************************************************************
# Processing 368...
# PSG not found for mesaid 368. Aborting...
# ********************************************************************************
# Could not get data for mesaid 368
# ********************************************************************************
# Processing 372...
# PSG not found for mesaid 372. Aborting...
# ********************************************************************************
# Could not get data for mesaid 372
# ********************************************************************************
# Processing 374...
# PSG not found for mesaid 374. Aborting...
# ********************************************************************************
# Could not get data for mesaid 374
# ********************************************************************************
# Processing 380...
# PSG not found for mesaid 380. Aborting...
# ********************************************************************************
# Could not get data for mesaid 380
# ********************************************************************************
# Processing 381...
# PSG not found for mesaid 381. Aborting...
# ********************************************************************************
# Could not get data for mesaid 381
# ********************************************************************************
# Processing 382...
# PSG not found for mesaid 382. Aborting...
# ********************************************************************************
# Could not get data for mesaid 382
# ********************************************************************************
# Processing 384...
# PSG not found for mesaid 384. Aborting...
# ********************************************************************************
# Could not get data for mesaid 384
# ********************************************************************************
# Processing 385...
# PSG not found for mesaid 385. Aborting...
# ********************************************************************************
# Could not get data for mesaid 385
# ********************************************************************************
# Processing 386...
# PSG not found for mesaid 386. Aborting...
# ********************************************************************************
# Could not get data for mesaid 386
# ********************************************************************************
# Processing 388...
# PSG not found for mesaid 388. Aborting...
# ********************************************************************************
# Could not get data for mesaid 388
# ********************************************************************************
# Processing 392...
# PSG not found for mesaid 392. Aborting...
# ********************************************************************************
# Could not get data for mesaid 392
# ********************************************************************************
# Processing 393...
# PSG not found for mesaid 393. Aborting...
# ********************************************************************************
# Could not get data for mesaid 393
# ********************************************************************************
# Processing 399...
# PSG not found for mesaid 399. Aborting...
# ********************************************************************************
# Could not get data for mesaid 399
# ********************************************************************************
# Processing 402...
# PSG not found for mesaid 402. Aborting...
# ********************************************************************************
# Could not get data for mesaid 402
# ********************************************************************************
# Processing 403...
# PSG not found for mesaid 403. Aborting...
# ********************************************************************************
# Could not get data for mesaid 403
# ********************************************************************************
# Processing 405...
# PSG not found for mesaid 405. Aborting...
# ********************************************************************************
# Could not get data for mesaid 405
# ********************************************************************************
# Processing 407...
# PSG not found for mesaid 407. Aborting...
# ********************************************************************************
# Could not get data for mesaid 407
# ********************************************************************************
# Processing 408...
# PSG not found for mesaid 408. Aborting...
# ********************************************************************************
# Could not get data for mesaid 408
# ********************************************************************************
# Processing 414...
# PSG not found for mesaid 414. Aborting...
# ********************************************************************************
# Could not get data for mesaid 414
# ********************************************************************************
# Processing 415...
# PSG not found for mesaid 415. Aborting...
# ********************************************************************************
# Could not get data for mesaid 415
# ********************************************************************************
# Processing 416...
# PSG not found for mesaid 416. Aborting...
# ********************************************************************************
# Could not get data for mesaid 416
# ********************************************************************************
# Processing 419...
# PSG not found for mesaid 419. Aborting...
# ********************************************************************************
# Could not get data for mesaid 419
# ********************************************************************************
# Processing 423...
# PSG not found for mesaid 423. Aborting...
# ********************************************************************************
# Could not get data for mesaid 423
# ********************************************************************************
# Processing 427...
# PSG not found for mesaid 427. Aborting...
# ********************************************************************************
# Could not get data for mesaid 427
# ********************************************************************************
# Processing 435...
# PSG not found for mesaid 435. Aborting...
# ********************************************************************************
# Could not get data for mesaid 435
# ********************************************************************************
# Processing 439...
# PSG not found for mesaid 439. Aborting...
# ********************************************************************************
# Could not get data for mesaid 439
# ********************************************************************************
# Processing 440...
# PSG not found for mesaid 440. Aborting...
# ********************************************************************************
# Could not get data for mesaid 440
# ********************************************************************************
# Processing 443...
# PSG not found for mesaid 443. Aborting...
# ********************************************************************************
# Could not get data for mesaid 443
# ********************************************************************************
# Processing 445...
# PSG not found for mesaid 445. Aborting...
# ********************************************************************************
# Could not get data for mesaid 445
# ********************************************************************************
# Processing 446...
# PSG not found for mesaid 446. Aborting...
# ********************************************************************************
# Could not get data for mesaid 446
# ********************************************************************************
# Processing 452...
# PSG not found for mesaid 452. Aborting...
# ********************************************************************************
# Could not get data for mesaid 452
# ********************************************************************************
# Processing 457...
# PSG not found for mesaid 457. Aborting...
# ********************************************************************************
# Could not get data for mesaid 457
# ********************************************************************************
# Processing 458...
# PSG not found for mesaid 458. Aborting...
# ********************************************************************************
# Could not get data for mesaid 458
# ********************************************************************************
# Processing 459...
# PSG not found for mesaid 459. Aborting...
# ********************************************************************************
# Could not get data for mesaid 459
# ********************************************************************************
# Processing 460...
# PSG not found for mesaid 460. Aborting...
# ********************************************************************************
# Could not get data for mesaid 460
# ********************************************************************************
# Processing 464...
# PSG not found for mesaid 464. Aborting...
# ********************************************************************************
# Could not get data for mesaid 464
# ********************************************************************************
# Processing 465...
# PSG not found for mesaid 465. Aborting...
# ********************************************************************************
# Could not get data for mesaid 465
# ********************************************************************************
# Processing 468...
# PSG not found for mesaid 468. Aborting...
# ********************************************************************************
# Could not get data for mesaid 468
# ********************************************************************************
# Processing 469...
# PSG not found for mesaid 469. Aborting...
# ********************************************************************************
# Could not get data for mesaid 469
# ********************************************************************************
# Processing 470...
# PSG not found for mesaid 470. Aborting...
# ********************************************************************************
# Could not get data for mesaid 470
# ********************************************************************************
# Processing 474...
# PSG not found for mesaid 474. Aborting...
# ********************************************************************************
# Could not get data for mesaid 474
# ********************************************************************************
# Processing 476...
# PSG not found for mesaid 476. Aborting...
# ********************************************************************************
# Could not get data for mesaid 476
# ********************************************************************************
# Processing 483...
# PSG not found for mesaid 483. Aborting...
# ********************************************************************************
# Could not get data for mesaid 483
# ********************************************************************************
# Processing 485...
# PSG not found for mesaid 485. Aborting...
# ********************************************************************************
# Could not get data for mesaid 485
# ********************************************************************************
# Processing 488...
# PSG not found for mesaid 488. Aborting...
# ********************************************************************************
# Could not get data for mesaid 488
# ********************************************************************************
# Processing 490...
# PSG not found for mesaid 490. Aborting...
# ********************************************************************************
# Could not get data for mesaid 490
# ********************************************************************************
# Processing 491...
# PSG not found for mesaid 491. Aborting...
# ********************************************************************************
# Could not get data for mesaid 491
# ********************************************************************************
# Processing 495...
# PSG not found for mesaid 495. Aborting...
# ********************************************************************************
# Could not get data for mesaid 495
# ********************************************************************************
# Processing 499...
# PSG not found for mesaid 499. Aborting...
# ********************************************************************************
# Could not get data for mesaid 499
# ********************************************************************************
# Processing 501...
# PSG not found for mesaid 501. Aborting...
# ********************************************************************************
# Could not get data for mesaid 501
# ********************************************************************************
# Processing 505...
# PSG not found for mesaid 505. Aborting...
# ********************************************************************************
# Could not get data for mesaid 505
# ********************************************************************************
# Processing 509...
# PSG not found for mesaid 509. Aborting...
# ********************************************************************************
# Could not get data for mesaid 509
# ********************************************************************************
# Processing 512...
# PSG not found for mesaid 512. Aborting...
# ********************************************************************************
# Could not get data for mesaid 512
# ********************************************************************************
# Processing 518...
# PSG not found for mesaid 518. Aborting...
# ********************************************************************************
# Could not get data for mesaid 518
# ********************************************************************************
# Processing 519...
# PSG not found for mesaid 519. Aborting...
# ********************************************************************************
# Could not get data for mesaid 519
# ********************************************************************************
# Processing 522...
# PSG not found for mesaid 522. Aborting...
# ********************************************************************************
# Could not get data for mesaid 522
# ********************************************************************************
# Processing 523...
# PSG not found for mesaid 523. Aborting...
# ********************************************************************************
# Could not get data for mesaid 523
# ********************************************************************************
# Processing 526...
# PSG not found for mesaid 526. Aborting...
# ********************************************************************************
# Could not get data for mesaid 526
# ********************************************************************************
# Processing 527...
# PSG not found for mesaid 527. Aborting...
# ********************************************************************************
# Could not get data for mesaid 527
# ********************************************************************************
# Processing 528...
# PSG not found for mesaid 528. Aborting...
# ********************************************************************************
# Could not get data for mesaid 528
# ********************************************************************************
# Processing 529...
# PSG not found for mesaid 529. Aborting...
# ********************************************************************************
# Could not get data for mesaid 529
# ********************************************************************************
# Processing 533...
# PSG not found for mesaid 533. Aborting...
# ********************************************************************************
# Could not get data for mesaid 533
# ********************************************************************************
# Processing 534...
# PSG not found for mesaid 534. Aborting...
# ********************************************************************************
# Could not get data for mesaid 534
# ********************************************************************************
# Processing 536...
# PSG not found for mesaid 536. Aborting...
# ********************************************************************************
# Could not get data for mesaid 536
# ********************************************************************************
# Processing 537...
# PSG not found for mesaid 537. Aborting...
# ********************************************************************************
# Could not get data for mesaid 537
# ********************************************************************************
# Processing 545...
# PSG not found for mesaid 545. Aborting...
# ********************************************************************************
# Could not get data for mesaid 545
# ********************************************************************************
# Processing 548...
# PSG not found for mesaid 548. Aborting...
# ********************************************************************************
# Could not get data for mesaid 548
# ********************************************************************************
# Processing 550...
# PSG not found for mesaid 550. Aborting...
# ********************************************************************************
# Could not get data for mesaid 550
# ********************************************************************************
# Processing 553...
# PSG not found for mesaid 553. Aborting...
# ********************************************************************************
# Could not get data for mesaid 553
# ********************************************************************************
# Processing 554...
# PSG not found for mesaid 554. Aborting...
# ********************************************************************************
# ...
# ********************************************************************************
# Could not get data for mesaid 6619
# ********************************************************************************
# Processing 6621...
# PSG not found for mesaid 6621. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6621
# ********************************************************************************
# Processing 6622...
# PSG not found for mesaid 6622. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6622
# ********************************************************************************
# Processing 6625...
# PSG not found for mesaid 6625. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6625
# ********************************************************************************
# Processing 6627...
# PSG not found for mesaid 6627. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6627
# ********************************************************************************
# Processing 6629...
# PSG not found for mesaid 6629. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6629
# ********************************************************************************
# Processing 6630...
# PSG not found for mesaid 6630. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6630
# ********************************************************************************
# Processing 6632...
# PSG not found for mesaid 6632. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6632
# ********************************************************************************
# Processing 6641...
# PSG not found for mesaid 6641. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6641
# ********************************************************************************
# Processing 6646...
# Actigraphy not found for mesaid 6646. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6646
# ********************************************************************************
# Processing 6648...
# PSG not found for mesaid 6648. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6648
# ********************************************************************************
# Processing 6653...
# PSG not found for mesaid 6653. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6653
# ********************************************************************************
# Processing 6655...
# PSG not found for mesaid 6655. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6655
# ********************************************************************************
# Processing 6656...
# PSG not found for mesaid 6656. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6656
# ********************************************************************************
# Processing 6657...
# PSG not found for mesaid 6657. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6657
# ********************************************************************************
# Processing 6663...
# PSG not found for mesaid 6663. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6663
# ********************************************************************************
# Processing 6671...
# PSG not found for mesaid 6671. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6671
# ********************************************************************************
# Processing 6672...
# PSG not found for mesaid 6672. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6672
# ********************************************************************************
# Processing 6680...
# PSG not found for mesaid 6680. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6680
# ********************************************************************************
# Processing 6682...
# PSG not found for mesaid 6682. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6682
# ********************************************************************************
# Processing 6685...
# PSG not found for mesaid 6685. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6685
# ********************************************************************************
# Processing 6686...
# Actigraphy not found for mesaid 6686. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6686
# ********************************************************************************
# Processing 6693...
# PSG not found for mesaid 6693. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6693
# ********************************************************************************
# Processing 6695...
# PSG not found for mesaid 6695. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6695
# ********************************************************************************
# Processing 6697...
# PSG not found for mesaid 6697. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6697
# ********************************************************************************
# Processing 6699...
# PSG not found for mesaid 6699. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6699
# ********************************************************************************
# Processing 6704...
# PSG not found for mesaid 6704. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6704
# ********************************************************************************
# Processing 6707...
# PSG not found for mesaid 6707. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6707
# ********************************************************************************
# Processing 6709...
# PSG not found for mesaid 6709. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6709
# ********************************************************************************
# Processing 6722...
# PSG not found for mesaid 6722. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6722
# ********************************************************************************
# Processing 6723...
# PSG not found for mesaid 6723. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6723
# ********************************************************************************
# Processing 6726...
# PSG not found for mesaid 6726. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6726
# ********************************************************************************
# Processing 6727...
# PSG not found for mesaid 6727. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6727
# ********************************************************************************
# Processing 6730...
# PSG not found for mesaid 6730. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6730
# ********************************************************************************
# Processing 6734...
# Actigraphy not found for mesaid 6734. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6734
# ********************************************************************************
# Processing 6737...
# Actigraphy not found for mesaid 6737. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6737
# ********************************************************************************
# Processing 6739...
# PSG not found for mesaid 6739. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6739
# ********************************************************************************
# Processing 6741...
# PSG not found for mesaid 6741. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6741
# ********************************************************************************
# Processing 6746...
# PSG not found for mesaid 6746. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6746
# ********************************************************************************
# Processing 6751...
# PSG not found for mesaid 6751. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6751
# ********************************************************************************
# Processing 6754...
# PSG not found for mesaid 6754. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6754
# ********************************************************************************
# Processing 6755...
# PSG not found for mesaid 6755. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6755
# ********************************************************************************
# Processing 6756...
# PSG not found for mesaid 6756. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6756
# ********************************************************************************
# Processing 6757...
# PSG not found for mesaid 6757. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6757
# ********************************************************************************
# Processing 6759...
# PSG not found for mesaid 6759. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6759
# ********************************************************************************
# Processing 6773...
# PSG not found for mesaid 6773. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6773
# ********************************************************************************
# Processing 6781...
# PSG not found for mesaid 6781. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6781
# ********************************************************************************
# Processing 6783...
# PSG not found for mesaid 6783. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6783
# ********************************************************************************
# Processing 6784...
# PSG not found for mesaid 6784. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6784
# ********************************************************************************
# Processing 6786...
# PSG not found for mesaid 6786. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6786
# ********************************************************************************
# Processing 6788...
# PSG not found for mesaid 6788. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6788
# ********************************************************************************
# Processing 6789...
# PSG not found for mesaid 6789. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6789
# ********************************************************************************
# Processing 6790...
# PSG not found for mesaid 6790. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6790
# ********************************************************************************
# Processing 6792...
# PSG not found for mesaid 6792. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6792
# ********************************************************************************
# Processing 6795...
# PSG not found for mesaid 6795. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6795
# ********************************************************************************
# Processing 6796...
# PSG not found for mesaid 6796. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6796
# ********************************************************************************
# Processing 6802...
# PSG not found for mesaid 6802. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6802
# ********************************************************************************
# Processing 6804...
# PSG not found for mesaid 6804. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6804
# ********************************************************************************
# Processing 6807...
# PSG not found for mesaid 6807. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6807
# ********************************************************************************
# Processing 6810...
# PSG not found for mesaid 6810. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6810
# ********************************************************************************
# Processing 6811...
# PSG not found for mesaid 6811. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6811
# ********************************************************************************
# Processing 6812...
# PSG not found for mesaid 6812. Aborting...
# ********************************************************************************
# Could not get data for mesaid 6812
# Done with 0 okay out of 2237 possible ids
